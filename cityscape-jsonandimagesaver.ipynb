# %%
import os
import sys
import random
import math
import numpy as np
import scipy.misc
import matplotlib
import matplotlib.pyplot as plt
import skimage
from skimage import io

import coco
import utils
import model as modellib
import visualize
import PIL

import json
import collections
import cv2

from PIL import Image

#%matplotlib inline 

# Root directory of the project
ROOT_DIR = os.getcwd()

# Directory to save logs and trained model
MODEL_DIR = os.path.join(ROOT_DIR, "logs")

# Path to trained weights file
# Download this file and place in the root of your 
# project (See README file for details)
COCO_MODEL_PATH = os.path.join(ROOT_DIR, "mask_rcnn_coco.h5")

# Directory of images to run detection on
IMAGE_DIR = "/home/kkshmz-rzm/bltb3-2/shibuya-4k/C0002"
# Out:
# /home/kkshmz-rzm/miniconda3/envs/shib34/lib/python3.4/site-packages/matplotlib/colors.py:298: MatplotlibDeprecationWarning: The is_string_like function was deprecated in version 2.1.
#   if cbook.is_string_like(arg):
# /home/kkshmz-rzm/miniconda3/envs/shib34/lib/python3.4/site-packages/matplotlib/colors.py:351: MatplotlibDeprecationWarning: The is_string_like function was deprecated in version 2.1.
#   if not cbook.is_string_like(arg) and cbook.iterable(arg):
# /home/kkshmz-rzm/miniconda3/envs/shib34/lib/python3.4/site-packages/matplotlib/colors.py:765: MatplotlibDeprecationWarning: The is_string_like function was deprecated in version 2.1.
#   not cbook.is_string_like(colors[0]):
#
# Bad key "_internal.classic_mode" on line 513 in
# /home/kkshmz-rzm/miniconda3/envs/shib34/lib/python3.4/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key "ytick.left" on line 251 in
# /home/kkshmz-rzm/miniconda3/envs/shib34/lib/python3.4/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key "lines.dotted_pattern" on line 20 in
# /home/kkshmz-rzm/miniconda3/envs/shib34/lib/python3.4/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key "date.autoformatter.microsecond" on line 229 in
# /home/kkshmz-rzm/miniconda3/envs/shib34/lib/python3.4/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key "boxplot.meanprops.marker" on line 360 in
# /home/kkshmz-rzm/miniconda3/envs/shib34/lib/python3.4/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key "xtick.major.bottom" on line 247 in
# /home/kkshmz-rzm/miniconda3/envs/shib34/lib/python3.4/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key "lines.scale_dashes" on line 21 in
# /home/kkshmz-rzm/miniconda3/envs/shib34/lib/python3.4/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution
# /home/kkshmz-rzm/miniconda3/envs/shib34/lib/python3.4/site-packages/matplotlib/__init__.py:1069: UserWarning: Bad val "auto" on line #353
# 	"boxplot.flierprops.markerfacecolor: auto
# "
# 	in file "/home/kkshmz-rzm/miniconda3/envs/shib34/lib/python3.4/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle"
# 	Key boxplot.flierprops.markerfacecolor: auto does not look like a color arg
#   (val, error_details, msg))
#
# Bad key "axes.titlepad" on line 177 in
# /home/kkshmz-rzm/miniconda3/envs/shib34/lib/python3.4/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key "xtick.minor.top" on line 248 in
# /home/kkshmz-rzm/miniconda3/envs/shib34/lib/python3.4/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key "boxplot.meanprops.markeredgecolor" on line 362 in
# /home/kkshmz-rzm/miniconda3/envs/shib34/lib/python3.4/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key "date.autoformatter.second" on line 228 in
# /home/kkshmz-rzm/miniconda3/envs/shib34/lib/python3.4/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key "ytick.right" on line 252 in
# /home/kkshmz-rzm/miniconda3/envs/shib34/lib/python3.4/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key "lines.dashed_pattern" on line 18 in
# /home/kkshmz-rzm/miniconda3/envs/shib34/lib/python3.4/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key "date.autoformatter.minute" on line 227 in
# /home/kkshmz-rzm/miniconda3/envs/shib34/lib/python3.4/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key "boxplot.meanprops.markersize" on line 363 in
# /home/kkshmz-rzm/miniconda3/envs/shib34/lib/python3.4/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key "ytick.major.right" on line 264 in
# /home/kkshmz-rzm/miniconda3/envs/shib34/lib/python3.4/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key "xtick.bottom" on line 235 in
# /home/kkshmz-rzm/miniconda3/envs/shib34/lib/python3.4/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key "ytick.major.left" on line 263 in
# /home/kkshmz-rzm/miniconda3/envs/shib34/lib/python3.4/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key "date.autoformatter.hour" on line 226 in
# /home/kkshmz-rzm/miniconda3/envs/shib34/lib/python3.4/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key "xtick.top" on line 234 in
# /home/kkshmz-rzm/miniconda3/envs/shib34/lib/python3.4/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key "date.autoformatter.year" on line 223 in
# /home/kkshmz-rzm/miniconda3/envs/shib34/lib/python3.4/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key "date.autoformatter.day" on line 225 in
# /home/kkshmz-rzm/miniconda3/envs/shib34/lib/python3.4/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key "axes.formatter.offset_threshold" on line 200 in
# /home/kkshmz-rzm/miniconda3/envs/shib34/lib/python3.4/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key "patch.force_edgecolor" on line 33 in
# /home/kkshmz-rzm/miniconda3/envs/shib34/lib/python3.4/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key "lines.dashdot_pattern" on line 19 in
# /home/kkshmz-rzm/miniconda3/envs/shib34/lib/python3.4/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key "scatter.marker" on line 338 in
# /home/kkshmz-rzm/miniconda3/envs/shib34/lib/python3.4/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key "boxplot.meanprops.markerfacecolor" on line 361 in
# /home/kkshmz-rzm/miniconda3/envs/shib34/lib/python3.4/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key "xtick.minor.bottom" on line 249 in
# /home/kkshmz-rzm/miniconda3/envs/shib34/lib/python3.4/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key "date.autoformatter.month" on line 224 in
# /home/kkshmz-rzm/miniconda3/envs/shib34/lib/python3.4/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key "hist.bins" on line 40 in
# /home/kkshmz-rzm/miniconda3/envs/shib34/lib/python3.4/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key "xtick.major.top" on line 246 in
# /home/kkshmz-rzm/miniconda3/envs/shib34/lib/python3.4/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key "hatch.color" on line 37 in
# /home/kkshmz-rzm/miniconda3/envs/shib34/lib/python3.4/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key "ytick.minor.right" on line 266 in
# /home/kkshmz-rzm/miniconda3/envs/shib34/lib/python3.4/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key "ytick.minor.left" on line 265 in
# /home/kkshmz-rzm/miniconda3/envs/shib34/lib/python3.4/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key "axes.autolimit_mode" on line 213 in
# /home/kkshmz-rzm/miniconda3/envs/shib34/lib/python3.4/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key "hatch.linewidth" on line 38 in
# /home/kkshmz-rzm/miniconda3/envs/shib34/lib/python3.4/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution
# tf.estimator package not installed.
# tf.estimator package not installed.
# Using TensorFlow backend.

# %%
class InferenceConfig(coco.CocoConfig):
    # Set batch size to 1 since we'll be running inference on
    # one image at a time. Batch size = GPU_COUNT * IMAGES_PER_GPU
    GPU_COUNT = 1
    IMAGES_PER_GPU = 1

config = InferenceConfig()
# config.print()

# %%
# Create model object in inference mode.
model = modellib.MaskRCNN(mode="inference", model_dir=MODEL_DIR, config=config)

# Load weights trained on MS-COCO
model.load_weights(COCO_MODEL_PATH, by_name=True)

# %%
# COCO Class names
# Index of the class in the list is its ID. For example, to get ID of
# the teddy bear class, use: class_names.index('teddy bear')
class_names = ['BG', 'person', 'bicycle', 'car', 'motorcycle', 'airplane',
               'bus', 'train', 'truck', 'boat', 'traffic light',
               'fire hydrant', 'stop sign', 'parking meter', 'bench', 'bird',
               'cat', 'dog', 'horse', 'sheep', 'cow', 'elephant', 'bear',
               'zebra', 'giraffe', 'backpack', 'umbrella', 'handbag', 'tie',
               'suitcase', 'frisbee', 'skis', 'snowboard', 'sports ball',
               'kite', 'baseball bat', 'baseball glove', 'skateboard',
               'surfboard', 'tennis racket', 'bottle', 'wine glass', 'cup',
               'fork', 'knife', 'spoon', 'bowl', 'banana', 'apple',
               'sandwich', 'orange', 'broccoli', 'carrot', 'hot dog', 'pizza',
               'donut', 'cake', 'chair', 'couch', 'potted plant', 'bed',
               'dining table', 'toilet', 'tv', 'laptop', 'mouse', 'remote',
               'keyboard', 'cell phone', 'microwave', 'oven', 'toaster',
               'sink', 'refrigerator', 'book', 'clock', 'vase', 'scissors',
               'teddy bear', 'hair drier', 'toothbrush']

# %%
#sys.path.append(os.path.join(ROOT_DIR, "samples/coco/"))  # To find local version
#import coco

#get_ipython().magic('matplotlib inline')

# Directory to save logs and trained model
MODEL_DIR = os.path.join(ROOT_DIR, "logs")

# Local path to trained weights file
COCO_MODEL_PATH = os.path.join(ROOT_DIR, "mask_rcnn_coco.h5")
# Download COCO trained weights from Releases if needed
if not os.path.exists(COCO_MODEL_PATH):
    utils.download_trained_weights(COCO_MODEL_PATH)


# Directory of images to run detection on


SAVE_DIR = os.path.join(ROOT_DIR, "output/C0002/")
with open('525.json', 'a') as outfile:
    for f in sorted(os.listdir(IMAGE_DIR)):
        print (f)
        image = io.imread(os.path.join(IMAGE_DIR,f))
        img = cv2.imread(os.path.join(IMAGE_DIR,f))
        results = model.detect([image],verbose=1)
        r = results[0]
        imagename = os.path.join(SAVE_DIR+f)
        visualize.save_image(image, imagename,r['rois'], r['masks'], r['class_ids'], r['scores'],class_names)
        for i in range(len(r['scores'])):
            y2 = r['rois'][i][2]
            y1 = r['rois'][i][0]
            bboxwidth = y2-y1
            x2 = r['rois'][i][3]
            x1 = r['rois'][i][1]
            bboxheight = x2-x1
            bboxcenter = (bboxwidth/2)+(bboxheight/2)
            dimensions = img.shape
            height = img.shape[0]
            width = img.shape[1]
            objectData = {}
            objectData['image_id'] = f
            objectData['class_id'] = class_names[int(r['class_ids'][i])]
            objectData['confidence'] = float(r['scores'][i])
            objectData['x'] = ((int(x2)-int(x1))/2)+x1
            objectData['y'] = ((int(y1)-int(y2))/2)+y1
           
            print(objectData)
            json.dump(objectData,outfile)
            outfile.write("\n")  
            
            # Add newline cause Py JSON does not
            
            
#             plt.savefig(os.path.join(SAVE_DIR, f),bbox_inches='tight', pad_inches=-0.5,orientation= 'landscape')
            #cv2.imwrite(os.path.join(SAVE_DIR, f), image)
#         print(r['scores'])
#         print(r['class_ids'])
#         objectData = {}
#         objectData['class_id'] = r['class_ids']
#         objectData['confidence'] = r['scores']
#         objectData['center'] = bboxcenter
#         print(objectData)
#         json.dump(objectData,outfile)
# Out:
# 000000001.bmp
# Processing 1 images
# image                    shape: (2160, 3840, 3)       min:    0.00000  max:  255.00000
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000
# image_metas              shape: (1, 89)               min:    0.00000  max: 3840.00000
# {'image_id': '000000001.bmp', 'confidence': 0.9911707639694214, 'class_id': 'bus', 'y': 933.5, 'x': 1066.5}
# {'image_id': '000000001.bmp', 'confidence': 0.9895338416099548, 'class_id': 'bus', 'y': 719.5, 'x': 669.0}
# {'image_id': '000000001.bmp', 'confidence': 0.9837918281555176, 'class_id': 'person', 'y': 1051.0, 'x': 2480.0}
# {'image_id': '000000001.bmp', 'confidence': 0.9780464768409729, 'class_id': 'person', 'y': 1066.5, 'x': 2030.0}
# {'image_id': '000000001.bmp', 'confidence': 0.9779855012893677, 'class_id': 'car', 'y': 1061.0, 'x': 3183.5}
# {'image_id': '000000001.bmp', 'confidence': 0.976679801940918, 'class_id': 'car', 'y': 1012.5, 'x': 3487.0}
# {'image_id': '000000001.bmp', 'confidence': 0.9719319939613342, 'class_id': 'person', 'y': 1021.5, 'x': 1961.0}
# {'image_id': '000000001.bmp', 'confidence': 0.971825897693634, 'class_id': 'car', 'y': 1083.0, 'x': 3067.0}
# {'image_id': '000000001.bmp', 'confidence': 0.9712950587272644, 'class_id': 'person', 'y': 1077.0, 'x': 2326.5}
# {'image_id': '000000001.bmp', 'confidence': 0.9605181217193604, 'class_id': 'person', 'y': 1044.0, 'x': 1871.0}
# {'image_id': '000000001.bmp', 'confidence': 0.9459137320518494, 'class_id': 'person', 'y': 1048.5, 'x': 1810.5}
# {'image_id': '000000001.bmp', 'confidence': 0.9444833397865295, 'class_id': 'person', 'y': 1044.0, 'x': 2407.0}
# {'image_id': '000000001.bmp', 'confidence': 0.9283373951911926, 'class_id': 'person', 'y': 1044.0, 'x': 1627.0}
# {'image_id': '000000001.bmp', 'confidence': 0.9137650728225708, 'class_id': 'person', 'y': 1034.0, 'x': 1932.5}
# {'image_id': '000000001.bmp', 'confidence': 0.9133172631263733, 'class_id': 'person', 'y': 1010.5, 'x': 3748.0}
# {'image_id': '000000001.bmp', 'confidence': 0.8956950902938843, 'class_id': 'person', 'y': 1052.0, 'x': 1784.5}
# {'image_id': '000000001.bmp', 'confidence': 0.8926848769187927, 'class_id': 'person', 'y': 1035.0, 'x': 3667.5}
# {'image_id': '000000001.bmp', 'confidence': 0.8863193988800049, 'class_id': 'person', 'y': 1048.5, 'x': 1840.5}
# {'image_id': '000000001.bmp', 'confidence': 0.8837100863456726, 'class_id': 'person', 'y': 1070.0, 'x': 1485.0}
# {'image_id': '000000001.bmp', 'confidence': 0.877387523651123, 'class_id': 'person', 'y': 1060.5, 'x': 1713.5}
# {'image_id': '000000001.bmp', 'confidence': 0.8765039443969727, 'class_id': 'person', 'y': 1051.5, 'x': 1602.5}
# {'image_id': '000000001.bmp', 'confidence': 0.8718445301055908, 'class_id': 'person', 'y': 1052.0, 'x': 1903.0}
# {'image_id': '000000001.bmp', 'confidence': 0.8547210097312927, 'class_id': 'person', 'y': 998.5, 'x': 3800.0}
# {'image_id': '000000001.bmp', 'confidence': 0.8326700925827026, 'class_id': 'person', 'y': 1072.0, 'x': 1501.5}
# {'image_id': '000000001.bmp', 'confidence': 0.8275497555732727, 'class_id': 'person', 'y': 1059.5, 'x': 1460.5}
# {'image_id': '000000001.bmp', 'confidence': 0.821820855140686, 'class_id': 'person', 'y': 1062.0, 'x': 1659.0}
# {'image_id': '000000001.bmp', 'confidence': 0.8187525868415833, 'class_id': 'person', 'y': 1061.5, 'x': 1524.0}
# {'image_id': '000000001.bmp', 'confidence': 0.8061148524284363, 'class_id': 'car', 'y': 1117.0, 'x': 2979.0}
# {'image_id': '000000001.bmp', 'confidence': 0.7795227766036987, 'class_id': 'person', 'y': 1066.0, 'x': 1428.0}
# {'image_id': '000000001.bmp', 'confidence': 0.7556467056274414, 'class_id': 'truck', 'y': 1002.5, 'x': 2861.0}
# {'image_id': '000000001.bmp', 'confidence': 0.7476699352264404, 'class_id': 'person', 'y': 1066.0, 'x': 1353.5}
# {'image_id': '000000001.bmp', 'confidence': 0.7257885932922363, 'class_id': 'person', 'y': 1058.5, 'x': 1758.5}
# {'image_id': '000000001.bmp', 'confidence': 0.719871997833252, 'class_id': 'person', 'y': 1066.0, 'x': 1546.5}
# {'image_id': '000000001.bmp', 'confidence': 0.7140038013458252, 'class_id': 'person', 'y': 1061.5, 'x': 1578.0}
# 000000002.bmp
# Processing 1 images
# image                    shape: (2160, 3840, 3)       min:    0.00000  max:  255.00000
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000
# image_metas              shape: (1, 89)               min:    0.00000  max: 3840.00000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-ffe26952acc3> in <module>()
#      24         image = io.imread(os.path.join(IMAGE_DIR,f))
#      25         img = cv2.imread(os.path.join(IMAGE_DIR,f))
# ---> 26         results = model.detect([image],verbose=1)
#      27         r = results[0]
#      28         imagename = os.path.join(SAVE_DIR+f)
#
# /home/kkshmz-rzm/bltb3-2/shibuya-4k/cityscape_MaskRCNN/model.py in detect(self, images, verbose)
#    2216         detections, mrcnn_class, mrcnn_bbox, mrcnn_mask, \
#    2217         rois, rpn_class, rpn_bbox =\
# -> 2218             self.keras_model.predict([molded_images, image_metas], verbose=0)
#    2219         # Process detections
#    2220         results = []
#
# /home/kkshmz-rzm/miniconda3/envs/shib34/lib/python3.4/site-packages/keras/engine/training.py in predict(self, x, batch_size, verbose, steps)
#    1167                                             batch_size=batch_size,
#    1168                                             verbose=verbose,
# -> 1169                                             steps=steps)
#    1170
#    1171     def train_on_batch(self, x, y,
#
# /home/kkshmz-rzm/miniconda3/envs/shib34/lib/python3.4/site-packages/keras/engine/training_arrays.py in predict_loop(model, f, ins, batch_size, verbose, steps)
#     292                 ins_batch[i] = ins_batch[i].toarray()
#     293
# --> 294             batch_outs = f(ins_batch)
#     295             batch_outs = to_list(batch_outs)
#     296             if batch_index == 0:
#
# /home/kkshmz-rzm/miniconda3/envs/shib34/lib/python3.4/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2713                 return self._legacy_call(inputs)
#    2714
# -> 2715             return self._call(inputs)
#    2716         else:
#    2717             if py_any(is_tensor(x) for x in inputs):
#
# /home/kkshmz-rzm/miniconda3/envs/shib34/lib/python3.4/site-packages/keras/backend/tensorflow_backend.py in _call(self, inputs)
#    2673             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2674         else:
# -> 2675             fetched = self._callable_fn(*array_vals)
#    2676         return fetched[:len(self.outputs)]
#    2677
#
# /home/kkshmz-rzm/miniconda3/envs/shib34/lib/python3.4/site-packages/tensorflow/python/client/session.py in __call__(self, *args, **kwargs)
#    1437           ret = tf_session.TF_SessionRunCallable(
#    1438               self._session._session, self._handle, args, status,
# -> 1439               run_metadata_ptr)
#    1440         if run_metadata:
#    1441           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:
